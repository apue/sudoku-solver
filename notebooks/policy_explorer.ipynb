# %% [markdown]
# # Sudoku Policy Explorer
# 使用 `sudoku_solver.notebook.visualizer` 在 Notebook 中回放策略步骤。

# %% [markdown]
# ## 环境准备
# 确保安装 `ipywidgets`：
# ```bash
# uv pip install ipywidgets ipycanvas
# ```

# %%
from sudoku_solver.notebook.visualizer import solve_for_notebook, build_policy_explorer, resolve_project_root

PROJECT_ROOT = resolve_project_root()
PUZZLE_PATH = PROJECT_ROOT / 'data/002.json'
POLICY = 'human-lite'

run = solve_for_notebook(PUZZLE_PATH, policy=POLICY)
run.metrics
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Developer/sudoku-solver/src/sudoku_solver/io/json_io.py:17, in load_puzzle(path)
#      16 try:
# ---> 17     obj = json.loads(Path(path).read_text())
#      18 except Exception as e:  # noqa: BLE001
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pathlib.py:1058, in Path.read_text(self, encoding, errors)
#    1057 encoding = io.text_encoding(encoding)
# -> 1058 with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1059     return f.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/002.json'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       3 PUZZLE_PATH = 'data/002.json'
#       4 POLICY = 'human-lite'
# ----> 6 run = solve_for_notebook(PUZZLE_PATH, policy=POLICY)
#       7 run.metrics
#
# File ~/Developer/sudoku-solver/src/sudoku_solver/notebook/visualizer.py:132, in solve_for_notebook(puzzle_path, policy, strategy_override)
#     130 """Run the solver with trace steps enabled for notebook visualization."""
#     131 puzzle_file = Path(puzzle_path)
# --> 132 grid = load_puzzle(puzzle_file)
#     133 base_grid = grid.clone()
#     134 import time
#
# File ~/Developer/sudoku-solver/src/sudoku_solver/io/json_io.py:19, in load_puzzle(path)
#      17     obj = json.loads(Path(path).read_text())
#      18 except Exception as e:  # noqa: BLE001
# ---> 19     raise ValueError(f"无法读取 JSON：{e}") from e
#      21 if not isinstance(obj, dict) or "grid" not in obj:
#      22     raise ValueError("输入必须包含 grid 字段")
#
# ValueError: 无法读取 JSON：[Errno 2] No such file or directory: 'data/002.json'

# %%
explorer = build_policy_explorer(PUZZLE_PATH, policy=POLICY, notebook_run=run)
explorer
